# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rc('font', family = 'AppleGothic')
plt.rc('axes', unicode_minus = False)

# %% [markdown]
# # 1. 데이터 불러오기 및 탐색

# %% [markdown]
# ## 1-1. 데이터 불러오기

# %%
train = pd.read_csv(os.path.join('..', 'W02', 'train.csv'))
test = pd.read_csv(os.path.join('..', 'W02', 'test.csv'))

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595212 entries, 0 to 595211
# Data columns (total 59 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              595212 non-null  int64
#  1   target          595212 non-null  int64
#  2   ps_ind_01       595212 non-null  int64
#  3   ps_ind_02_cat   595212 non-null  int64
#  4   ps_ind_03       595212 non-null  int64
#  5   ps_ind_04_cat   595212 non-null  int64
#  6   ps_ind_05_cat   595212 non-null  int64
#  7   ps_ind_06_bin   595212 non-null  int64
#  8   ps_ind_07_bin   595212 non-null  int64
#  9   ps_ind_08_bin   595212 non-null  int64
#  10  ps_ind_09_bin   595212 non-null  int64
#  11  ps_ind_10_bin   595212 non-null  int64
#  12  ps_ind_11_bin   595212 non-null  int64
#  13  ps_ind_12_bin   595212 non-null  int64
#  14  ps_ind_13_bin   595212 non-null  int64
#  15  ps_ind_14       595212 non-null  int64
#  16  ps_ind_15       595212 non-null  int64
#  17  ps_ind_16_bin   595212 non-null  int64
#  18  ps_ind_17_bin   595212 non-null  int64
#  19  ps_ind_18_bin   595212 non-null  int64
#  20  ps_reg_01       595212 non-null  float64
#  21  ps_reg_02       595212 non-null  float64
#  22  ps_reg_03       595212 non-null  float64
#  23  ps_car_01_cat   595212 non-null  int64
#  24  ps_car_02_cat   595212 non-null  int64
#  25  ps_car_03_cat   595212 non-null  int64
#  26  ps_car_04_cat   595212 non-null  int64
#  27  ps_car_05_cat   595212 non-null  int64
#  28  ps_car_06_cat   595212 non-null  int64
#  29  ps_car_07_cat   595212 non-null  int64
#  30  ps_car_08_cat   595212 non-null  int64
#  31  ps_car_09_cat   595212 non-null  int64
#  32  ps_car_10_cat   595212 non-null  int64
#  33  ps_car_11_cat   595212 non-null  int64
#  34  ps_car_11       595212 non-null  int64
#  35  ps_car_12       595212 non-null  float64
#  36  ps_car_13       595212 non-null  float64
#  37  ps_car_14       595212 non-null  float64
#  38  ps_car_15       595212 non-null  float64
#  39  ps_calc_01      595212 non-null  float64
#  40  ps_calc_02      595212 non-null  float64
#  41  ps_calc_03      595212 non-null  float64
#  42  ps_calc_04      595212 non-null  int64
#  43  ps_calc_05      595212 non-null  int64
#  44  ps_calc_06      595212 non-null  int64
#  45  ps_calc_07      595212 non-null  int64
#  46  ps_calc_08      595212 non-null  int64
#  47  ps_calc_09      595212 non-null  int64
#  48  ps_calc_10      595212 non-null  int64
#  49  ps_calc_11      595212 non-null  int64
#  50  ps_calc_12      595212 non-null  int64
#  51  ps_calc_13      595212 non-null  int64
#  52  ps_calc_14      595212 non-null  int64
#  53  ps_calc_15_bin  595212 non-null  int64
#  54  ps_calc_16_bin  595212 non-null  int64
#  55  ps_calc_17_bin  595212 non-null  int64
#  56  ps_calc_18_bin  595212 non-null  int64
#  57  ps_calc_19_bin  595212 non-null  int64
#  58  ps_calc_20_bin  595212 non-null  int64
# dtypes: float64(10), int64(49)
# memory usage: 267.9 MB

# %% [markdown]
# ## 1-2. 변수 정리하기, 메타데이터 생성

# %%
def segColumns(df):
    meta = []
    for column in df.columns:
        role = "input"
        if 'bin' in column or column == 'target':
            level = 'binary'
        elif 'cat' in column:
            level = 'nominal'
        elif df[column].dtype == 'int64':
            level = 'ordinal'
        else:
            level = 'interval' 
        keep = 'True'
        dtype = df[column].dtype
        
        if column == 'id':
            level = 'nominal'
            role = 'target'
            keep = 'False'
        
        meta.append([column, role, level, keep, dtype])
        
    meta = pd.DataFrame(meta, columns = ['varname', 'role', 'level', 'keep', 'dtype'])
    return meta

# %%
meta = segColumns(train)

# %%
meta.index = meta['varname']
meta.name = 'varname'
meta = meta.drop('varname', axis = 1)
meta.head()
# Out:
#                  role    level   keep  dtype
# varname
# id             target  nominal  False  int64
# target          input   binary   True  int64
# ps_ind_01       input  ordinal   True  int64
# ps_ind_02_cat   input  nominal   True  int64
# ps_ind_03       input  ordinal   True  int64

# %% [markdown]
# ## 1-3. Porto 데이터셋의 열에 대한 요약 통계 및 결측치 확인

# %%
test[meta[(meta['level'] == 'ordinal') | (meta['level'] == 'interval')].index].describe()
# Out:
#            ps_ind_01      ps_ind_03      ps_ind_14      ps_ind_15  \
# count  892816.000000  892816.000000  892816.000000  892816.000000
# mean        1.902371       4.413734       0.012383       7.296862
# std         1.986503       2.700149       0.127251       3.541948
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       2.000000       0.000000       5.000000
# 50%         1.000000       4.000000       0.000000       7.000000
# 75%         3.000000       6.000000       0.000000      10.000000
# max         7.000000      11.000000       4.000000      13.000000
#
#            ps_reg_01      ps_reg_02      ps_reg_03      ps_car_11  \
# count  892816.000000  892816.000000  892816.000000  892816.000000
# mean        0.611057       0.439868       0.551740       2.346606
# std         0.287699       0.404678       0.794023       0.831666
# min         0.000000       0.000000      -1.000000      -1.000000
# 25%         0.400000       0.200000       0.524404       2.000000
# 50%         0.700000       0.300000       0.721110       3.000000
# 75%         0.900000       0.600000       1.002185       3.000000
# max         0.900000       1.800000       4.423517       3.000000
#
#            ps_car_12      ps_car_13  ...     ps_calc_05     ps_calc_06  \
# count  892816.000000  892816.000000  ...  892816.000000  892816.000000
# mean        0.379957       0.813637  ...       1.885328       7.687805
# std         0.058385       0.224779  ...       1.136763       1.333521
# min         0.141421       0.275778  ...       0.000000       1.000000
# 25%         0.316228       0.671234  ...       1.000000       7.000000
# 50%         0.374166       0.766081  ...       2.000000       8.000000
# 75%         0.400000       0.906132  ...       3.000000       9.000000
# max         1.264911       4.031301  ...       6.000000      10.000000
#
#           ps_calc_07     ps_calc_08     ps_calc_09     ps_calc_10  \
# count  892816.000000  892816.000000  892816.000000  892816.000000
# mean        3.009537       9.225854       2.338538       8.443167
# std         1.415155       1.460560       1.248601       2.906361
# min         0.000000       1.000000       0.000000       0.000000
# 25%         2.000000       8.000000       1.000000       6.000000
# 50%         3.000000       9.000000       2.000000       8.000000
# 75%         4.000000      10.000000       3.000000      10.000000
# max         9.000000      12.000000       7.000000      25.000000
#
#           ps_calc_11     ps_calc_12     ps_calc_13     ps_calc_14
# count  892816.000000  892816.000000  892816.000000  892816.000000
# mean        5.438478       1.440265       2.875013       7.540367
# std         2.330081       1.200620       1.694072       2.745882
# min         0.000000       0.000000       0.000000       0.000000
# 25%         4.000000       1.000000       2.000000       6.000000
# 50%         5.000000       1.000000       3.000000       7.000000
# 75%         7.000000       2.000000       4.000000       9.000000
# max        20.000000      11.000000      15.000000      28.000000
#
# [8 rows x 26 columns]

# %%
# 결측치 확인 
(train == -1).sum()
# Out:
# id                     0
# target                 0
# ps_ind_01              0
# ps_ind_02_cat        216
# ps_ind_03              0
# ps_ind_04_cat         83
# ps_ind_05_cat       5809
# ps_ind_06_bin          0
# ps_ind_07_bin          0
# ps_ind_08_bin          0
# ps_ind_09_bin          0
# ps_ind_10_bin          0
# ps_ind_11_bin          0
# ps_ind_12_bin          0
# ps_ind_13_bin          0
# ps_ind_14              0
# ps_ind_15              0
# ps_ind_16_bin          0
# ps_ind_17_bin          0
# ps_ind_18_bin          0
# ps_reg_01              0
# ps_reg_02              0
# ps_reg_03         107772
# ps_car_01_cat        107
# ps_car_02_cat          5
# ps_car_03_cat     411231
# ps_car_04_cat          0
# ps_car_05_cat     266551
# ps_car_06_cat          0
# ps_car_07_cat      11489
# ps_car_08_cat          0
# ps_car_09_cat        569
# ps_car_10_cat          0
# ps_car_11_cat          0
# ps_car_11              5
# ps_car_12              1
# ps_car_13              0
# ps_car_14          42620
# ps_car_15              0
# ps_calc_01             0
# ps_calc_02             0
# ps_calc_03             0
# ps_calc_04             0
# ps_calc_05             0
# ps_calc_06             0
# ps_calc_07             0
# ps_calc_08             0
# ps_calc_09             0
# ps_calc_10             0
# ps_calc_11             0
# ps_calc_12             0
# ps_calc_13             0
# ps_calc_14             0
# ps_calc_15_bin         0
# ps_calc_16_bin         0
# ps_calc_17_bin         0
# ps_calc_18_bin         0
# ps_calc_19_bin         0
# ps_calc_20_bin         0
# dtype: int64

# %% [markdown]
# ## 1-4. Meta를 이용하여  nominal을 제외한 나머지 변수 각각 기술통계(describe)

# %%
train[meta.loc[meta['level'] != 'nominal'].index].describe()
# Out:
#               target      ps_ind_01      ps_ind_03  ps_ind_06_bin  \
# count  595212.000000  595212.000000  595212.000000  595212.000000
# mean        0.036448       1.900378       4.423318       0.393742
# std         0.187401       1.983789       2.699902       0.488579
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       2.000000       0.000000
# 50%         0.000000       1.000000       4.000000       0.000000
# 75%         0.000000       3.000000       6.000000       1.000000
# max         1.000000       7.000000      11.000000       1.000000
#
#        ps_ind_07_bin  ps_ind_08_bin  ps_ind_09_bin  ps_ind_10_bin  \
# count  595212.000000  595212.000000  595212.000000  595212.000000
# mean        0.257033       0.163921       0.185304       0.000373
# std         0.436998       0.370205       0.388544       0.019309
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         1.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#        ps_ind_11_bin  ps_ind_12_bin  ...     ps_calc_11     ps_calc_12  \
# count  595212.000000  595212.000000  ...  595212.000000  595212.000000
# mean        0.001692       0.009439  ...       5.441382       1.441918
# std         0.041097       0.096693  ...       2.332871       1.202963
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.000000       0.000000  ...       4.000000       1.000000
# 50%         0.000000       0.000000  ...       5.000000       1.000000
# 75%         0.000000       0.000000  ...       7.000000       2.000000
# max         1.000000       1.000000  ...      19.000000      10.000000
#
#           ps_calc_13     ps_calc_14  ps_calc_15_bin  ps_calc_16_bin  \
# count  595212.000000  595212.000000   595212.000000   595212.000000
# mean        2.872288       7.539026        0.122427        0.627840
# std         1.694887       2.746652        0.327779        0.483381
# min         0.000000       0.000000        0.000000        0.000000
# 25%         2.000000       6.000000        0.000000        0.000000
# 50%         3.000000       7.000000        0.000000        1.000000
# 75%         4.000000       9.000000        0.000000        1.000000
# max        13.000000      23.000000        1.000000        1.000000
#
#        ps_calc_17_bin  ps_calc_18_bin  ps_calc_19_bin  ps_calc_20_bin
# count   595212.000000   595212.000000   595212.000000   595212.000000
# mean         0.554182        0.287182        0.349024        0.153318
# std          0.497056        0.452447        0.476662        0.360295
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        0.000000        0.000000        0.000000
# 50%          1.000000        0.000000        0.000000        0.000000
# 75%          1.000000        1.000000        1.000000        0.000000
# max          1.000000        1.000000        1.000000        1.000000
#
# [8 rows x 44 columns]

# %% [markdown]
# ## 1-5. Target 값 분포 시각화 및 살펴보기

# %%
train.target.value_counts().plot.bar()
plt.show()

# %% [markdown]
# # 2. 데이터 품질 검사

# %% [markdown]
# ## 2-1. 결측치 확인 및 처리하기

# %%
# 결측치가 존재하는 컬럼
(train == -1).sum().sort_values(ascending = False)[:13]
# Out:
# ps_car_03_cat    411231
# ps_car_05_cat    266551
# ps_reg_03        107772
# ps_car_14         42620
# ps_car_07_cat     11489
# ps_ind_05_cat      5809
# ps_car_09_cat       569
# ps_ind_02_cat       216
# ps_car_01_cat       107
# ps_ind_04_cat        83
# ps_car_02_cat         5
# ps_car_11             5
# ps_car_12             1
# dtype: int64

# %%
# 결측치의 비율이 높은 ['ps_car_03_cat', 'ps_car_05_cat'] 삭제
(train == -1).sum().sort_values(ascending = False)[:13] / train.shape[0]
# Out:
# ps_car_03_cat    0.690898
# ps_car_05_cat    0.447825
# ps_reg_03        0.181065
# ps_car_14        0.071605
# ps_car_07_cat    0.019302
# ps_ind_05_cat    0.009760
# ps_car_09_cat    0.000956
# ps_ind_02_cat    0.000363
# ps_car_01_cat    0.000180
# ps_ind_04_cat    0.000139
# ps_car_02_cat    0.000008
# ps_car_11        0.000008
# ps_car_12        0.000002
# dtype: float64

# %%
train = train.drop(['ps_car_03_cat', 'ps_car_05_cat'], axis = 1)
test = test.drop(['ps_car_03_cat', 'ps_car_05_cat'], axis = 1)

# %%
meta = meta.drop(['ps_car_03_cat', 'ps_car_05_cat'])

# %%
# 결측값(-1) 처리가 필요한 칼럼
modify_columns = ((train == -1).sum().sort_values(ascending = False)[:13] / train.shape[0]).index

# %%
meta.loc[modify_columns]
# Out:
#                 role     level  keep    dtype
# ps_reg_03      input  interval  True  float64
# ps_car_14      input  interval  True  float64
# ps_car_07_cat  input   nominal  True    int64
# ps_ind_05_cat  input   nominal  True    int64
# ps_car_09_cat  input   nominal  True    int64
# ps_ind_02_cat  input   nominal  True    int64
# ps_car_01_cat  input   nominal  True    int64
# ps_ind_04_cat  input   nominal  True    int64
# ps_car_11      input   ordinal  True    int64
# ps_car_02_cat  input   nominal  True    int64
# ps_car_12      input  interval  True  float64
# ps_reg_02      input  interval  True  float64
# ps_reg_01      input  interval  True  float64

# %%
# ordinal -> 가장 빈도 높은 것으로
# interval -> mean으로
# nominal -> 가장 빈도 높은 것 or 결측치 자체로

# %%
ordinal_columns = meta[meta['level'] == 'ordinal'].index
interval_columns = meta[meta['level'] == 'interval'].index

# %%
def fillNA(df, columns, types):
    if types == 'ordinal':
        for column in columns:
            most_value = df[column].value_counts().index[0]
            df.loc[df[column] == -1, column] = most_value
    elif types == 'interval':
        for column in columns:
            mean_value = round(df[column].mean(),2)
            df.loc[df[column] == -1, column] = mean_value
    return df

# %%
train = fillNA(train, ordinal_columns, 'ordinal')
train = fillNA(train, interval_columns, 'interval')

# %%
test = fillNA(test, ordinal_columns, 'ordinal')
test = fillNA(test, interval_columns, 'interval')

# %% [markdown]
# ## 2-2 nominal 데이터의 유니크값 개수 확인하기

# %%
# 'ps_car_11_cat'은 104개의 범주값을 가짐
train[meta[meta['level'] == 'nominal'].index].nunique()
# Out:
# id               595212
# ps_ind_02_cat         5
# ps_ind_04_cat         3
# ps_ind_05_cat         8
# ps_car_01_cat        13
# ps_car_02_cat         3
# ps_car_04_cat        10
# ps_car_06_cat        18
# ps_car_07_cat         3
# ps_car_08_cat         2
# ps_car_09_cat         6
# ps_car_10_cat         3
# ps_car_11_cat       104
# dtype: int64

# %%
meta.loc['ps_car_11_cat']['keep'] = 'False'

# %% [markdown]
# # 3. 데이터시각화

# %% [markdown]
# ## 3-1. 범주형 변수 catplot

# %%
cat_columns = meta.loc[(meta['level'] == 'nominal') & (meta['keep'] == 'True')].index

# %%
import matplotlib.gridspec as gridspec
gs = gridspec.GridSpec(1, 2)
gs0 = gridspec.GridSpecFromSubplotSpec(3, 3, subplot_spec=gs[0])
gs1 = gridspec.GridSpecFromSubplotSpec(2, 2, subplot_spec=gs[1])

fig = plt.figure(figsize = (40,15))

for i, column in list(zip(np.arange(12), cat_columns)):
    ax = fig.add_subplot(gs0[i//3, i%3])
    sns.barplot(ax = ax, data = train, y = 'target', x = column) # 각 범주값에 따른 target의 평균
    
    if i == 8:
        break

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,6))
sns.barplot(ax = ax[0], data = train, y = 'target', x = cat_columns[-1])
sns.barplot(ax = ax[1], data = train, y = 'target', x = cat_columns[-2])
plt.show()

# %%
# 결측치가 존재하는 category columns
(train == -1).sum().sort_values(ascending = False)[:7]
# Out:
# ps_car_07_cat    11489
# ps_ind_05_cat     5809
# ps_car_09_cat      569
# ps_ind_02_cat      216
# ps_car_01_cat      107
# ps_ind_04_cat       83
# ps_car_02_cat        5
# dtype: int64

# %%
na_cat_columns = (train == -1).sum().sort_values(ascending = False)[:7].index

# %%
labels = [0, 2, 1, 4, 9, 1, 1]

# %%
# 결측치의 barplot이 가까운 범주로 넘기기
def changeNA(df):
    for column, i in zip(na_cat_columns, labels):
        df.loc[df[column] == -1, column] = i
    return df

# %%
train = changeNA(train)

# %%
test = changeNA(test)

# %% [markdown]
# ## 3-2. continous 데이터 seaborn heatmap 그려보기

# %%
temp = train[meta[meta['level'] == 'interval'].index]
plt.figure(figsize = (12,12))
sns.heatmap(temp.corr(), fmt='.2f', annot = True, cmap = 'summer')
plt.show()

# %% [markdown]
# ## 3-3. 상관계수가 0.5이상인 변수들만 개별적으로 seaborn lmplot 그려보기(단, hue=’target’)

# %%
cor = temp.corr()

# %%
cor = cor.replace(1, 0)

# %%
cor = abs(cor)

# %%
v = []
for column in cor.columns:
    idx = cor.loc[cor[column] > 0.5, column].index
    for i in idx:
        v.append((column, i))

# %%
for x,y in v:
    sns.lmplot(data = train, x = x, y = y, hue = 'target')

# %% [markdown]
# ## 3-4. ordinal 데이터 각각 target 값에 따라 boxplot 그려보기

# %%
ord_columns = meta[meta['level'] == 'ordinal'].index

# %%
gs0 = gridspec.GridSpecFromSubplotSpec(4, 4, subplot_spec=gs[0])
fig = plt.figure(figsize = (40,15))

for i, column in list(zip(np.arange(17), ord_columns)):
    ax = fig.add_subplot(gs0[i//4, i%4])
    plt.boxplot( data = train, x = column)

# %% [markdown]
# # 4. 피처엔지니어링

# %% [markdown]
# ## 4-1. nominal 변수 원핫인코딩

# %%
cat_columns = meta[(meta['level'] == 'nominal') & (meta['keep'] == 'True')].index

# %%
for column in cat_columns:
    train[column] = train[column].astype(object)

# %%
for column in cat_columns:
    test[column] = test[column].astype(object)

# %%
data = pd.get_dummies(train)

# %%
data_test = pd.get_dummies(test)

# %% [markdown]
# ## 4-2. 언더샘플링

# %%
# 데이터가 매우 불균형한 상태
data.target.value_counts()
# Out:
# 0    573518
# 1     21694
# Name: target, dtype: int64

# %%
idx = data['id']
X = data.iloc[:,2:]
y = data['target']

# %%
idx_test = data_test['id']
X_test = data_test.iloc[:,1:]

# %%
from imblearn.under_sampling import *

# %%
X_samp, y_samp = RandomUnderSampler(sampling_strategy = 0.3, replacement = False).fit_sample(X, y)

# %%
# 3:7 정도의 비율을 가지게 되었음
y_samp.value_counts()
# Out:
# 0    72313
# 1    21694
# Name: target, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
X_samp = scaler.fit_transform(X_samp)

# %%
X_samp = pd.DataFrame(X_samp, columns = X.columns)

# %%
X_test = scaler.fit_transform(X_test)
X_test = pd.DataFrame(X_test, columns = X.columns)

# %% [markdown]
# ## 4-3. randomforest의 feature_importance를 통해 중요도 하위 50%의 변수 제거

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfo = RandomForestClassifier(n_estimators=1000, n_jobs=-1, random_state=42)

# %%
rfo.fit(X_samp, y_samp)
importances = rfo.feature_importances_

# %%
n_features = np.arange(X_samp.shape[1])

# %%
plt.figure(figsize = (20,20))
plt.barh(n_features, importances, align='center')
plt.yticks(n_features, X_samp.columns)
plt.ylim(-1, n_features[-1])
plt.show()

# %%
pd.DataFrame(list(zip(X_samp.columns, importances)), columns = ['column', 'importance']).sort_values('importance', ascending = False)
# Out:
#               column  importance
# 21         ps_car_13    0.052996
# 17         ps_reg_03    0.047404
# 22         ps_car_14    0.039280
# 33        ps_calc_10    0.033441
# 37        ps_calc_14    0.032889
# ..               ...         ...
# 9      ps_ind_13_bin    0.000145
# 78   ps_car_04_cat_7    0.000077
# 110  ps_car_10_cat_2    0.000069
# 6      ps_ind_10_bin    0.000061
# 75   ps_car_04_cat_4    0.000042
#
# [111 rows x 2 columns]

# %%
from sklearn.feature_selection import SelectFromModel

# %%
selected = SelectFromModel(rfo, threshold='median', prefit=True)

# %%
selected_columns = X_samp.columns[selected.get_support()]

# %%
# 선택된 변수들
selected_columns
# Out:
# Index(['ps_ind_01', 'ps_ind_03', 'ps_ind_06_bin', 'ps_ind_07_bin',
#        'ps_ind_08_bin', 'ps_ind_09_bin', 'ps_ind_15', 'ps_ind_16_bin',
#        'ps_ind_17_bin', 'ps_ind_18_bin', 'ps_reg_01', 'ps_reg_02', 'ps_reg_03',
#        'ps_car_11_cat', 'ps_car_11', 'ps_car_12', 'ps_car_13', 'ps_car_14',
#        'ps_car_15', 'ps_calc_01', 'ps_calc_02', 'ps_calc_03', 'ps_calc_04',
#        'ps_calc_05', 'ps_calc_06', 'ps_calc_07', 'ps_calc_08', 'ps_calc_09',
#        'ps_calc_10', 'ps_calc_11', 'ps_calc_12', 'ps_calc_13', 'ps_calc_14',
#        'ps_calc_15_bin', 'ps_calc_16_bin', 'ps_calc_17_bin', 'ps_calc_18_bin',
#        'ps_calc_19_bin', 'ps_calc_20_bin', 'ps_ind_02_cat_1',
#        'ps_ind_02_cat_2', 'ps_ind_04_cat_0', 'ps_ind_04_cat_1',
#        'ps_ind_05_cat_0', 'ps_car_01_cat_6', 'ps_car_01_cat_7',
#        'ps_car_01_cat_10', 'ps_car_01_cat_11', 'ps_car_04_cat_0',
#        'ps_car_06_cat_0', 'ps_car_06_cat_1', 'ps_car_06_cat_11',
#        'ps_car_06_cat_14', 'ps_car_09_cat_0', 'ps_car_09_cat_1',
#        'ps_car_09_cat_2'],
#       dtype='object')

# %%
X_selected = pd.DataFrame(selected.transform(X_samp), columns = selected_columns)

# %%
X_test_selected = X_test[selected_columns]

# %% [markdown]
# # 5. 모델링

# %% [markdown]
# # 5-1. StratifiedKFold 진행 (seed부여)

# %%
from sklearn.model_selection import StratifiedKFold

# %%
skf = StratifiedKFold(n_splits=3, random_state = 42)
# Out:
# /Users/jinseok/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
models = [RandomForestClassifier(), GradientBoostingClassifier()]

# %%
scores = []
for m in zip(['RFO', 'GBM'], models):
    for i, (idx_train, idx_valid) in enumerate(skf.split(X_selected, y_samp)):
        x_train = X_selected.iloc[idx_train]
        y_train = y_samp.iloc[idx_train]
        x_valid = X_selected.iloc[idx_valid]
        y_valid = y_samp.iloc[idx_valid]

        model = m[1]
        result = model.fit(x_train, y_train)

        pred = result.predict(x_valid)
        score = result.score(x_valid, y_valid)
        scores.append(score)
        
    print(m[0], np.mean(scores))
# Out:
# RFO 0.769591624405988
# GBM 0.7699798970423967

# %% [markdown]
# ## 5-2. Submission

# %%
pred = model.predict_proba(X_test_selected)

# %%
sub = pd.read_csv('./sample_submission.csv')

# %%
sub['target'] = pred[:,1]

# %%
sub.to_csv('./submission_1.csv', index = False)
